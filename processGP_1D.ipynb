# %%
try:
    from pyDOE import lhs
except:
    _=!pip install pyDOE
    from pyDOE import lhs

try:
    import GPy
except:
    _=!pip install GPy
    import GPy

from GP_Bayesian_inference import DoJobs
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
from theano import function, shared, tensor as tt

# %%
# generate initial training dataset
def GenerateSample(num_simulations,bounds):
    # Specify how many simulations you can afford:
    X_scaled = lhs(1, num_simulations)

    # Let's get to the original space
    X_sampled = X_scaled * (bounds[1] - bounds[0]) + bounds[0]
    X_sampled = X_sampled[:,0]
    X_sampled.sort()  
    return X_sampled

def RunFunction(xx):
  x1 = xx[:,0]
  x2 = xx[:,1]
  # Branin function
  return (-1.275/np.pi**2 * x1**2 + 5./np.pi * x1 + x2 - 6.)**2 \
        +(10. - 5./4./np.pi) * np.cos(x1) + 10.

def RunFunction1(xx):
    return 0.5*np.exp(xx) + 0.05 * np.sin(3.*np.pi*xx)

def RunFunction2(xx):
    #return 1.*np.exp(xx) + 0.05 * np.cos(3.*np.pi*xx)
    return .5*np.exp(-xx) + 0.05 * np.cos(-3.*np.pi*xx)

# %%
dims = 1
num_sim = 5
data_x = np.loadtxt('test_data_%iD_T%i.txt'%(dims,num_sim))[:,0] # test data(observation)
Xtr = np.loadtxt('x_sampled_%iD_T%i.txt'%(dims,num_sim)) # training data

X_range = np.array([-2, 2])

if Xtr.ndim == 1:
    Xtr_m, Xtr_s = np.mean(Xtr), np.std(Xtr)
    Xtr_scaled = (Xtr - Xtr_m) / Xtr_s
else:
    Xtr_m, Xtr_s = np.mean(Xtr, axis=1), np.std(Xtr,axis=1)
    Xtr_scaled = (Xtr - Xtr_m[:,None]) / Xtr_s[:,None]

Ytr1 = RunFunction1(Xtr)
Ytr1_m, Ytr1_s = np.mean(Ytr1), np.std(Ytr1)
Ytr1_scaled = (Ytr1 - Ytr1_m) / Ytr1_s


# test data(observation)
if Xtr.ndim == 1:
    data_x_scaled = (data_x - Xtr_m) / Xtr_s
else:
    data_x_scaled = (data_x - Xtr_m[:,None]) / Xtr_s[:,None]

data1 = RunFunction1(data_x)
data1_scaled = (data1 - Ytr1_m) / Ytr1_s

# plotting points
xtest = np.linspace(X_range[0], X_range[1], 200)
if Xtr.ndim == 1:
    xtest_scaled = (xtest - Xtr_m) / Xtr_s
else:
    xtest_scaled = (xtest - Xtr_m[:,None]) / Xtr_s[:,None]

fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(Xtr,Ytr1,color='r',marker='x',label='Taining dataset',zorder=2)
ax.plot(xtest,RunFunction1(xtest),color='r',label='True function',zorder=1)
ax.scatter(data_x,data1,color='c',marker='o', facecolors='none',label='Test dataset',zorder=3)

ax.legend(frameon=True,bbox_to_anchor=(1.03,1.03),fontsize=20)
ax.tick_params(axis='both', labelsize=20)
ax.set_xlabel('$X$',fontsize=20)
ax.set_ylabel('$y$',fontsize=20)

fig.savefig('Example_%iD_T%i.pdf'%(dims,num_sim),dpi=300)
np.savetxt('true_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([xtest[:,None],RunFunction1(xtest)[:,None]]), fmt='%.6f')
np.savetxt('training_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([Xtr[:,None],Ytr1[:,None]]), fmt='%.6f')
np.savetxt('test_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([data_x[:,None],data1[:,None]]), fmt='%.6f')

# %%
if Xtr_scaled.ndim == 1:
    Xtr_scaled = Xtr_scaled[:, None]

k1 = GPy.kern.RBF(Xtr_scaled.shape[1], ARD=True)
m1 = GPy.models.GPRegression(Xtr_scaled, Ytr1_scaled[:, None], k1)#, noise_var=1e-10

m1[".*Gaussian_noise"] = m1.Y.var() * 0.01
m1[".*Gaussian_noise"].fix()
m1.optimize(max_iters = 500)
m1[".*Gaussian_noise"].unfix()
m1[".*Gaussian_noise"].constrain_positive()
print('*' * 80)
print('Optimized model:')
print(m1)
m1.optimize_restarts(30, optimizer = "bfgs",  max_iters = 1000)
# Out:
# reconstraining parameters GP_regression.Gaussian_noise.variance
# ********************************************************************************
# Optimized model:
#
# Name : GP regression
# Objective : 4.534717435102256
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |     1.866939512487068  |      +ve      |
#   rbf.lengthscale          |    1.1075950713297855  |      +ve      |
#   Gaussian_noise.variance  |  0.009999999999999998  |      +ve      |
# Optimization restart 1/30, f = 3.30356364642272
# Optimization restart 2/30, f = 3.3035645721301474
# Optimization restart 3/30, f = 3.303563535878968
# Optimization restart 4/30, f = 3.3035638173431443
# Optimization restart 5/30, f = 3.3035649765689117
# Optimization restart 6/30, f = 3.3035640705266003
# Optimization restart 7/30, f = 3.303563537696612
# Optimization restart 8/30, f = 3.3035635414513447
# Optimization restart 9/30, f = 3.303563532535885
# Optimization restart 10/30, f = 3.303563532255643
# Optimization restart 11/30, f = 3.303563585581889
# Optimization restart 12/30, f = 3.3035635932642182
# Optimization restart 13/30, f = 3.303563531698784
# Optimization restart 14/30, f = 3.3035635448942133
# Optimization restart 15/30, f = 3.303563603143041
# Optimization restart 16/30, f = 3.3035635470040603
# Optimization restart 17/30, f = 3.303563543633838
# Optimization restart 18/30, f = 3.3035638678582258
# Optimization restart 19/30, f = 3.30356589761409
# Optimization restart 20/30, f = 3.3035635310455143
# Optimization restart 21/30, f = 3.3035637384307464
# Optimization restart 22/30, f = 3.303563556140328
# Optimization restart 23/30, f = 3.303569745012559
# Optimization restart 24/30, f = 3.3035635572297304
# Optimization restart 25/30, f = 3.3035636063938423
# Optimization restart 26/30, f = 3.3035635792668714
# Optimization restart 27/30, f = 3.303566669288784
# Optimization restart 28/30, f = 3.303563612682755
# Optimization restart 29/30, f = 3.303563978229692
# Optimization restart 30/30, f = 3.3035638065095023
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f07890>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e1e210>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6712bf6b50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f672ddd4dd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f673043f710>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6712bf6410>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f672ddd45d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f67328eb2d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f671caedfd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6712bf0510>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f672ddd4290>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e6c350>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e6c250>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e6c990>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e228d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e22a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e22390>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e22590>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e22ed0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e6cf10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e221d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e229d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f70450>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f70750>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f70b90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f99090>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f079d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f70e10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711f70490>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6711e86650>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f6712bf6c90>]

# %%
l1 = m1.rbf.lengthscale[0]
s1 = m1.rbf.variance[0]
sig1 = m1.Gaussian_noise.variance[0]

print(l1,s1,sig1)
# Out:
# 1.6711864538231482 5.06120278579152 2.986225149874914e-12

# %%
sigma2 = .1
ls = l1
ss = s1
sigs = sig1
for i in range(num_sim):
    GPGP = DoJobs(dims, m1,sigma2, i, num_sim,ls,ss,sigs,X_range,Xtr_scaled,Ytr1_scaled,data1_scaled,6)
    GPGP.RunInference()
# Out:
#  /usr/local/lib/python3.7/dist-packages/pymc3/gp/cov.py:97: UserWarning:Only 1 column(s) out of Subtensor{int64}.0 are being used to compute the covariance function. If this is not intended, increase 'input_dim' parameter to the number of columns to use. Ignore otherwise.
# -0.7174629843595445
#  /content/GP_Bayesian_inference.py:178: FutureWarning:In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (6 chains in 1 job)
# NUTS: [x_1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:09<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:08<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:08<00:00 Sampling chain 2, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:09<00:00 Sampling chain 3, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:08<00:00 Sampling chain 4, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3000' class='' max='3000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3000/3000 00:08<00:00 Sampling chain 5, 0 divergences]
#     </div>
# Sampling 6 chains for 1_000 tune and 2_000 draw iterations (6_000 + 12_000 draws total) took 52 seconds.
# The number of effective samples is smaller than 25% for some parameters.
# Got error No model on context stack. trying to find log_likelihood in translation.
#  /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning:Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
# Got error No model on context stack. trying to find log_likelihood in translation.
# By sampling
#  x_1        -0.792
# x[0]       -0.792
# Mp[0]      -0.642
# Vp[0, 0]    0.005
# Name: mean, dtype: float64
#  /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning:Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
# x_max:  -1.1585687576831585
# 1th inference result
# prediction: -1.426789, true: -1.769328
# relative error: 0.193598
# function value at prediction: 0.109259
# true function value: 0.126399
#  /content/GP_Bayesian_inference.py:266: VisibleDeprecationWarning:Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:01<00:00]
#     </div>
