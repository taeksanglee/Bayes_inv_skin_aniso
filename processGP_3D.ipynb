# %%
try:
    from pyDOE import lhs
except:
    _=!pip install pyDOE
    from pyDOE import lhs
try:
    import GPy
except:
    _=!pip install GPy
    import GPy

from GP_Bayesian_inference_tripple import DoJobs
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
from theano import function, shared, tensor as tt

# %%
# generate initial training dataset
def GenerateSample(num_simulations,bounds):
    # Specify how many simulations you can afford:
    X_scaled = lhs(1, num_simulations)

    # Let's get to the original space
    X_sampled = X_scaled * (bounds[1] - bounds[0]) + bounds[0]
    X_sampled = X_sampled[:,0]
    X_sampled.sort() 
    return X_sampled

def RunFunction(xx):
  x1 = xx[:,0]
  x2 = xx[:,1]
  # Branin function
  return (-1.275/np.pi**2 * x1**2 + 5./np.pi * x1 + x2 - 6.)**2 \
        +(10. - 5./4./np.pi) * np.cos(x1) + 10.

def RunFunction1(xx):
    return 0.5*np.exp(xx) + 0.05 * np.sin(3.*np.pi*xx)

def RunFunction2(xx):
    return .5*np.exp(-xx) + 0.05 * np.cos(-3.*np.pi*xx)

def RunFunction3(xx):
    return -xx**2 + 0.05 * np.cos(-3.*np.pi*xx) +4

# %%
dims = 3
num_sim = 25
data_x = np.loadtxt('test_data_%iD_T%i.txt'%(dims,num_sim))[:,0] # test data(observation)
Xtr = np.loadtxt('x_sampled_%iD_T%i.txt'%(dims,num_sim)) # training data

X_range = np.array([-2, 2])

if Xtr.ndim == 1:
    Xtr_m, Xtr_s = np.mean(Xtr), np.std(Xtr)
    Xtr_scaled = (Xtr - Xtr_m) / Xtr_s
else:
    Xtr_m, Xtr_s = np.mean(Xtr, axis=1), np.std(Xtr,axis=1)
    Xtr_scaled = (Xtr - Xtr_m[:,None]) / Xtr_s[:,None]

Ytr1 = RunFunction1(Xtr)
Ytr1_m, Ytr1_s = np.mean(Ytr1), np.std(Ytr1)
Ytr1_scaled = (Ytr1 - Ytr1_m) / Ytr1_s

Ytr2 = RunFunction2(Xtr)
Ytr2_m, Ytr2_s = np.mean(Ytr2), np.std(Ytr2)
Ytr2_scaled = (Ytr2 - Ytr2_m) / Ytr2_s

Ytr3 = RunFunction3(Xtr)
Ytr3_m, Ytr3_s = np.mean(Ytr3), np.std(Ytr3)
Ytr3_scaled = (Ytr3 - Ytr3_m) / Ytr3_s

# test data(observation)
if Xtr.ndim == 1:
    data_x_scaled = (data_x - Xtr_m) / Xtr_s
else:
    data_x_scaled = (data_x - Xtr_m[:,None]) / Xtr_s[:,None]

data1 = RunFunction1(data_x)
data1_scaled = (data1 - Ytr1_m) / Ytr1_s

data2 = RunFunction2(data_x)
data2_scaled = (data2 - Ytr2_m) / Ytr2_s

data3 = RunFunction3(data_x)
data3_scaled = (data3 - Ytr3_m) / Ytr3_s

# plotting points
xtest = np.linspace(X_range[0], X_range[1], 200)
if Xtr.ndim == 1:
    xtest_scaled = (xtest - Xtr_m) / Xtr_s
else:
    xtest_scaled = (xtest - Xtr_m[:,None]) / Xtr_s[:,None]

fig, ax = plt.subplots(figsize=(6,6))
ax.scatter(Xtr,Ytr1,color='r',marker='x',label='Taining dataset #1',zorder=2)
ax.scatter(Xtr,Ytr2,color='m',marker='x',label='Taining dataset #2',zorder=2)
ax.scatter(Xtr,Ytr3,color='g',marker='x',label='Taining dataset #3',zorder=2)
ax.plot(xtest,RunFunction1(xtest),color='r',label='True function #1',zorder=1)
ax.plot(xtest,RunFunction2(xtest),color='m',label='True function #2',zorder=1)
ax.plot(xtest,RunFunction3(xtest),color='g',label='True function #3',zorder=1)
ax.scatter(data_x,data1,color='darkorange',marker='o', facecolors='none',label='Test dataset #1',zorder=3)
ax.scatter(data_x,data2,color='darkorange',marker='^', facecolors='none',label='Test dataset #2',zorder=3)
ax.scatter(data_x,data3,color='darkorange',marker='v', facecolors='none',label='Test dataset #3',zorder=3)
ax.legend(frameon=True,bbox_to_anchor=(1.03,1.03),fontsize=20)
ax.tick_params(axis='both', labelsize=20)
ax.set_xlabel('$X$',fontsize=20)
ax.set_ylabel('$y$',fontsize=20)

fig.savefig('Example_%iD_T%i.pdf'%(dims,num_sim),dpi=300)
np.savetxt('true_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([xtest[:,None],RunFunction1(xtest)[:,None],RunFunction2(xtest)[:,None],RunFunction3(xtest)[:,None]]), fmt='%.6f')
np.savetxt('training_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([Xtr[:,None],Ytr1[:,None],Ytr2[:,None],Ytr3[:,None]]), fmt='%.6f')
np.savetxt('test_data_%iD_T%i.txt'%(dims,num_sim), np.hstack([data_x[:,None],data1[:,None],data2[:,None],data3[:,None]]), fmt='%.6f')

# %%
if Xtr_scaled.ndim == 1:
    Xtr_scaled = Xtr_scaled[:, None]

k1 = GPy.kern.RBF(Xtr_scaled.shape[1], ARD=True)
k2 = GPy.kern.RBF(Xtr_scaled.shape[1], ARD=True)
k3 = GPy.kern.RBF(Xtr_scaled.shape[1], ARD=True)
if Ytr1_scaled.ndim == 1:
    print('here1')
    m1 = GPy.models.GPRegression(Xtr_scaled, Ytr1_scaled[:, None], k1)#, noise_var=1e-10
    m2 = GPy.models.GPRegression(Xtr_scaled, Ytr2_scaled[:, None], k2)
    m3 = GPy.models.GPRegression(Xtr_scaled, Ytr3_scaled[:, None], k3)
else:
    print('here2')
    m1 = GPy.models.GPRegression(Xtr_scaled, Ytr1_scaled, k1)#, noise_var=1e-10
    m2 = GPy.models.GPRegression(Xtr_scaled, Ytr2_scaled, k2)
    m3 = GPy.models.GPRegression(Xtr_scaled, Ytr3_scaled, k3)

m1[".*Gaussian_noise"] = m1.Y.var() * 0.01
m1[".*Gaussian_noise"].fix()
m1.optimize(max_iters = 500)
m1[".*Gaussian_noise"].unfix()
m1[".*Gaussian_noise"].constrain_positive()
print('*' * 80)
print('Optimized model:')
print(m1)
m1.optimize_restarts(30, optimizer = "bfgs",  max_iters = 1000)
# Out:
# reconstraining parameters GP_regression.Gaussian_noise.variance
# here1
# ********************************************************************************
# Optimized model:
#
# Name : GP regression
# Objective : -13.970794016163612
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   rbf.variance             |  13.162931874395511  |      +ve      |
#   rbf.lengthscale          |  1.7434358619635895  |      +ve      |
#   Gaussian_noise.variance  |                0.01  |      +ve      |
# Optimization restart 1/30, f = -23.101698266220982
# Optimization restart 2/30, f = -23.101698265774004
# Optimization restart 3/30, f = -48.09348776149929
# Optimization restart 4/30, f = -23.10169826614507
# Optimization restart 5/30, f = -23.101698266248444
# Optimization restart 6/30, f = -23.101698266282195
# Optimization restart 7/30, f = -23.101698266212065
# Optimization restart 8/30, f = -48.09348492550432
# Optimization restart 9/30, f = -23.10169826626084
# Optimization restart 10/30, f = -48.09348771411054
# Optimization restart 11/30, f = -23.10169826630043
# Optimization restart 12/30, f = -23.101698266213138
# Optimization restart 13/30, f = -23.10169826628135
# Optimization restart 14/30, f = -23.101698266287
# Optimization restart 15/30, f = -23.1016982661347
# Optimization restart 16/30, f = -23.10169826607734
# Optimization restart 17/30, f = -23.10169826609209
# Optimization restart 18/30, f = -23.10169826489556
# Optimization restart 19/30, f = -23.10169826627194
# Optimization restart 20/30, f = -48.093487663617445
# Optimization restart 21/30, f = -23.10169826624776
# Optimization restart 22/30, f = -23.101698266240977
# Optimization restart 23/30, f = -23.10169818777862
# Optimization restart 24/30, f = -48.09348702494565
# Optimization restart 25/30, f = -23.10169826625365
# Optimization restart 26/30, f = -48.093487717548705
# Optimization restart 27/30, f = -23.10169826623046
# Optimization restart 28/30, f = -48.0934863762514
# Optimization restart 29/30, f = -23.101698266269516
# Optimization restart 30/30, f = -23.1016982662228
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f438f2aafd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3c90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edf5a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f439928fe90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e509c10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f43a9c92a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a5c10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e5717d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a7490>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f30d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f38d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e5214d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521710>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521210>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521410>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd110>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd910>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dda50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521450>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3750>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3d50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f36d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3e10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f32d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3e50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521890>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521790>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521810>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521250>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e5219d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521290>]

# %%
m2[".*Gaussian_noise"] = m2.Y.var() * 0.01
m2[".*Gaussian_noise"].fix()
m2.optimize(max_iters = 500)
m2[".*Gaussian_noise"].unfix()
m2[".*Gaussian_noise"].constrain_positive()
print('*' * 80)
print('Optimized model:')
print(m2)
m2.optimize_restarts(30, optimizer = "bfgs",  max_iters = 1000)
# Out:
# reconstraining parameters GP_regression.Gaussian_noise.variance
# ********************************************************************************
# Optimized model:
#
# Name : GP regression
# Objective : -13.988744680100071
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   rbf.variance             |    13.428312203834931  |      +ve      |
#   rbf.lengthscale          |    1.7905841280740231  |      +ve      |
#   Gaussian_noise.variance  |  0.010000000000000002  |      +ve      |
# Optimization restart 1/30, f = -22.076216237298958
# Optimization restart 2/30, f = -22.07621623726124
# Optimization restart 3/30, f = -22.076216237310444
# Optimization restart 4/30, f = -22.076216237242374
# Optimization restart 5/30, f = -22.076216237315897
# Optimization restart 6/30, f = -22.07621623728014
# Optimization restart 7/30, f = -22.07621623717923
# Optimization restart 8/30, f = -22.076216237325074
# Optimization restart 9/30, f = -22.076216237272774
# Optimization restart 10/30, f = -22.07621623730249
# Optimization restart 11/30, f = -22.07621623724544
# Optimization restart 12/30, f = -47.76844290514185
# Optimization restart 13/30, f = -22.07621623562915
# Optimization restart 14/30, f = -22.07621623730666
# Optimization restart 15/30, f = -22.076216236766474
# Optimization restart 16/30, f = -22.07621623737481
# Optimization restart 17/30, f = -22.076216237217658
# Optimization restart 18/30, f = -22.076216236931035
# Optimization restart 19/30, f = -22.07621623624201
# Optimization restart 20/30, f = -22.07621623729659
# Optimization restart 21/30, f = -22.076216221331233
# Optimization restart 22/30, f = -22.076216237330925
# Optimization restart 23/30, f = -22.076216237302972
# Optimization restart 24/30, f = -22.076216236486317
# Optimization restart 25/30, f = -47.768414351847454
# Optimization restart 26/30, f = -22.076216183440142
# Optimization restart 27/30, f = -22.07621623725063
# Optimization restart 28/30, f = -22.076216237331217
# Optimization restart 29/30, f = -22.076216237296865
# Optimization restart 30/30, f = -22.07621623733278
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec92ed0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e574550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ed31f50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a5090>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec92fd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edf5590>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec92910>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec92e90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddf90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ed31d90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ed31150>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec92f50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6b50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521c50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521a10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521c10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e5210d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e521f50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e5217d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6790>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6e50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6a50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6f10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6b90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6690>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6bd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6d10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e66d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6ed0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6cd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec9bd90>]

# %%
m3[".*Gaussian_noise"] = m3.Y.var() * 0.1
m3[".*Gaussian_noise"].fix()
m3.optimize(max_iters = 500)
m3[".*Gaussian_noise"].unfix()
m3[".*Gaussian_noise"].constrain_positive()
print('*' * 80)
print('Optimized model:')
print(m3)
m3.optimize_restarts(30, optimizer = "bfgs",  max_iters = 1000)
# Out:
# reconstraining parameters GP_regression.Gaussian_noise.variance
# ********************************************************************************
# Optimized model:
#
# Name : GP regression
# Objective : 7.108080547787581
# Number of Parameters : 3
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   rbf.variance             |      18.442703694835  |      +ve      |
#   rbf.lengthscale          |    2.127965859185206  |      +ve      |
#   Gaussian_noise.variance  |  0.09999999999999999  |      +ve      |
# Optimization restart 1/30, f = -27.829854971411127
# Optimization restart 2/30, f = -27.82985497138482
# Optimization restart 3/30, f = -27.829854971684867
# Optimization restart 4/30, f = -27.829854971698722
# Optimization restart 5/30, f = -27.82985497167131
# Optimization restart 6/30, f = -49.11974316656908
# Optimization restart 7/30, f = -27.829854971603158
# Optimization restart 8/30, f = -27.829854971674003
# Optimization restart 9/30, f = -49.119740583903585
# Optimization restart 10/30, f = -27.829854971656363
# Optimization restart 11/30, f = -27.82985497154544
# Optimization restart 12/30, f = -27.82985497171246
# Optimization restart 13/30, f = -27.8298549716959
# Optimization restart 14/30, f = -27.829854904093104
# Optimization restart 15/30, f = -27.829854971706936
# Optimization restart 16/30, f = -27.829854971019955
# Optimization restart 17/30, f = -27.82985497170389
# Optimization restart 18/30, f = -27.82985497168939
# Optimization restart 19/30, f = -27.82985497169465
# Optimization restart 20/30, f = -27.829854971692686
# Optimization restart 21/30, f = -27.82985497166742
# Optimization restart 22/30, f = -27.829854971655497
# Optimization restart 23/30, f = -27.829854971256704
# Optimization restart 24/30, f = -27.82985497162162
# Optimization restart 25/30, f = -27.829854971659657
# Optimization restart 26/30, f = -27.829854971676667
# Optimization restart 27/30, f = -27.829854971716056
# Optimization restart 28/30, f = -27.8298549717337
# Optimization restart 29/30, f = -27.82985497169398
# Optimization restart 30/30, f = -27.829854971675566
# [<paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a5550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a7150>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e528bd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e574210>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ec9b910>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4e6310>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edb25d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4f3550>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edb2750>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edb2f10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4a7350>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438edb2190>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddf50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd210>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dde90>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dde50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd850>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddc50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddcd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd7d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd590>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dded0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddd10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd3d0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddfd0>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4ddb50>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd090>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dd390>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438e4dda10>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ecb2890>,
#  <paramz.optimization.optimization.opt_lbfgsb at 0x7f438ecf9210>]

# %%
l1 = m1.rbf.lengthscale[0]
s1 = m1.rbf.variance[0]
sig1 = m1.Gaussian_noise.variance[0]

l2 = m2.rbf.lengthscale[0]
s2 = m2.rbf.variance[0]
sig2 = m2.Gaussian_noise.variance[0]

l3 = m3.rbf.lengthscale[0]
s3 = m3.rbf.variance[0]
sig3 = m3.Gaussian_noise.variance[0]

np.savetxt('hyperparameters_3D_T%i.txt'%num_sim,[l1,s1,sig1,l2,s2,sig2,l3,s3,sig3],fmt='%.6f')
print(l1,s1,sig1,'\n',l2,s2,sig2,'\n',l3,s3,sig3)
# Out:
# 0.37606076444812286 2.006897142592485 3.272489529567351e-16
#  0.36945836403624 1.7023754587745312 6.437116836334619e-16
#  0.39119291091453706 2.756214176992605 4.3079146575710716e-16

# %%
sigma2 = .1
ls = np.array([l1,l2,l3])
ss = np.array([s1,s2,s3])
sigs = np.array([sig1,sig2,sig3])

for i in range(num_sim):
    GPGP = DoJobs(dims, m1,m2,m3, sigma2, i, num_sim,ls,ss,sigs,X_range,Xtr_scaled,Ytr1_scaled,Ytr2_scaled,Ytr3_scaled,data1_scaled,data2_scaled,data3_scaled)
    GPGP.RunInference()
# Out:
#  /usr/local/lib/python3.7/dist-packages/pymc3/gp/cov.py:97: UserWarning:Only 1 column(s) out of Subtensor{int64}.0 are being used to compute the covariance function. If this is not intended, increase 'input_dim' parameter to the number of columns to use. Ignore otherwise.
#  /usr/local/lib/python3.7/dist-packages/pymc3/gp/cov.py:97: UserWarning:Only 1 column(s) out of Subtensor{int64}.0 are being used to compute the covariance function. If this is not intended, increase 'input_dim' parameter to the number of columns to use. Ignore otherwise.
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
#  /content/GP_Bayesian_inference_tripple.py:202: FutureWarning:In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (6 chains in 1 job)
# NUTS: [x_1]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:23<00:00 Sampling chain 0, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:16<00:00 Sampling chain 1, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:16<00:00 Sampling chain 2, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:17<00:00 Sampling chain 3, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:19<00:00 Sampling chain 4, 0 divergences]
#     </div>
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:17<00:00 Sampling chain 5, 0 divergences]
#     </div>
# Sampling 6 chains for 1_000 tune and 3_000 draw iterations (6_000 + 18_000 draws total) took 111 seconds.
# The rhat statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Got error No model on context stack. trying to find log_likelihood in translation.
#  /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning:Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
# Got error No model on context stack. trying to find log_likelihood in translation.
# By sampling
#  x_1    -1.050
# x[0]   -1.050
# Mp1    -0.112
# Vp1     0.032
# Mp2     2.011
# Vp2     0.027
# Mp3    -2.105
# Vp3     0.042
# Name: mean, dtype: float64
#  /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3_3x.py:102: FutureWarning:Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
# x_max:  1.9960911199412552
# 1th inference result
# prediction: 2.342214, true: -1.909646
# relative error: 2.226518
# function1 value at prediction: 4.510934
# function2 value at prediction: -0.097570
# function3 value at prediction: -1.251948
# true1 function value: 0.111682
# true2 function value: 3.408290
# true3 function value: 0.386192
#  /content/GP_Bayesian_inference_tripple.py:339: VisibleDeprecationWarning:Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
